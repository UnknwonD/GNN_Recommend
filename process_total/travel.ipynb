# %%
import pandas as pd

# %%
df = pd.read_csv('./merged_csv/여행객_total.csv')

# %%
df.shape
# Out:
# (11520, 36)

# %%
df.drop('JOB_ETC', axis=1, inplace=True)

# %%
df['GENDER'] = df['GENDER'].map({'남': 1, '여': 2})

# %%
df.head().T
# Out:
#                                                0                      1  \
# TRAVELER_ID                              g002178                g004485
# RESIDENCE_SGG_CD                              29                     30
# GENDER                                         2                      1
# AGE_GRP                                       20                     40
# EDU_NM                                         6                      7
# EDU_FNSH_SE                                  1.0                    5.0
# MARR_STTS                                      1                      1
# FAMILY_MEMB                                    3                      2
# JOB_NM                                        12                      2
# INCOME                                         2                      5
# HOUSE_INCOME                                 7.0                   10.0
# TRAVEL_TERM                                    3                      2
# TRAVEL_NUM                                     4                      2
# TRAVEL_LIKE_SIDO_1                            50                     48
# TRAVEL_LIKE_SGG_1                          50130                  48840
# TRAVEL_LIKE_SIDO_2                            50                     48
# TRAVEL_LIKE_SGG_2                          50110                  48220
# TRAVEL_LIKE_SIDO_3                            26                     26
# TRAVEL_LIKE_SGG_3                          26500                  26500
# TRAVEL_STYL_1                                  1                      1
# TRAVEL_STYL_2                                  1                      1
# TRAVEL_STYL_3                                  1                      3
# TRAVEL_STYL_4                                  3                      6
# TRAVEL_STYL_5                                  3                      4
# TRAVEL_STYL_6                                  2                      2
# TRAVEL_STYL_7                                  6                      7
# TRAVEL_STYL_8                                  6                      7
# TRAVEL_STATUS_RESIDENCE                    광주광역시                  대전광역시
# TRAVEL_STATUS_DESTINATION                     전남                     전북
# TRAVEL_STATUS_ACCOMPANY              2인 여행(가족 외)            2인 여행(가족 외)
# TRAVEL_STATUS_YMD          2023-06-14~2023-06-15  2023-07-28~2023-07-29
# TRAVEL_MOTIVE_1                                1                      1
# TRAVEL_MOTIVE_2                              3.0                    2.0
# TRAVEL_MOTIVE_3                              9.0                    3.0
# TRAVEL_COMPANIONS_NUM                          1                      1
#
#                                                2                      3  \
# TRAVELER_ID                              g005167                g002887
# RESIDENCE_SGG_CD                              11                     28
# GENDER                                         1                      2
# AGE_GRP                                       20                     30
# EDU_NM                                         6                      5
# EDU_FNSH_SE                                  1.0                    1.0
# MARR_STTS                                      1                      2
# FAMILY_MEMB                                    3                      2
# JOB_NM                                         1                      3
# INCOME                                         4                      5
# HOUSE_INCOME                                 7.0                    8.0
# TRAVEL_TERM                                    3                      2
# TRAVEL_NUM                                     7                      1
# TRAVEL_LIKE_SIDO_1                            46                     42
# TRAVEL_LIKE_SGG_1                          46710                  42150
# TRAVEL_LIKE_SIDO_2                            45                     42
# TRAVEL_LIKE_SGG_2                          45190                  42210
# TRAVEL_LIKE_SIDO_3                            47                     28
# TRAVEL_LIKE_SGG_3                          47170                  28710
# TRAVEL_STYL_1                                  2                      2
# TRAVEL_STYL_2                                  3                      2
# TRAVEL_STYL_3                                  1                      3
# TRAVEL_STYL_4                                  4                      2
# TRAVEL_STYL_5                                  6                      3
# TRAVEL_STYL_6                                  3                      5
# TRAVEL_STYL_7                                  1                      2
# TRAVEL_STYL_8                                  7                      6
# TRAVEL_STATUS_RESIDENCE                    서울특별시                  인천광역시
# TRAVEL_STATUS_DESTINATION                     전남                     대전
# TRAVEL_STATUS_ACCOMPANY              2인 여행(가족 외)            2인 여행(가족 외)
# TRAVEL_STATUS_YMD          2023-09-07~2023-09-09  2023-07-01~2023-07-02
# TRAVEL_MOTIVE_1                                7                      2
# TRAVEL_MOTIVE_2                              5.0                    1.0
# TRAVEL_MOTIVE_3                              1.0                    3.0
# TRAVEL_COMPANIONS_NUM                          1                      1
#
#                                                4
# TRAVELER_ID                              g004189
# RESIDENCE_SGG_CD                              41
# GENDER                                         1
# AGE_GRP                                       20
# EDU_NM                                         6
# EDU_FNSH_SE                                  1.0
# MARR_STTS                                      1
# FAMILY_MEMB                                    4
# JOB_NM                                         4
# INCOME                                         4
# HOUSE_INCOME                                 9.0
# TRAVEL_TERM                                    2
# TRAVEL_NUM                                     2
# TRAVEL_LIKE_SIDO_1                            42
# TRAVEL_LIKE_SGG_1                          42150
# TRAVEL_LIKE_SIDO_2                            50
# TRAVEL_LIKE_SGG_2                          50110
# TRAVEL_LIKE_SIDO_3                            26
# TRAVEL_LIKE_SGG_3                          26350
# TRAVEL_STYL_1                                  2
# TRAVEL_STYL_2                                  1
# TRAVEL_STYL_3                                  2
# TRAVEL_STYL_4                                  4
# TRAVEL_STYL_5                                  6
# TRAVEL_STYL_6                                  5
# TRAVEL_STYL_7                                  6
# TRAVEL_STYL_8                                  5
# TRAVEL_STATUS_RESIDENCE                      경기도
# TRAVEL_STATUS_DESTINATION                     충남
# TRAVEL_STATUS_ACCOMPANY              2인 여행(가족 외)
# TRAVEL_STATUS_YMD          2023-07-18~2023-07-19
# TRAVEL_MOTIVE_1                                2
# TRAVEL_MOTIVE_2                              3.0
# TRAVEL_MOTIVE_3                              1.0
# TRAVEL_COMPANIONS_NUM                          1

# %%
# 사용할 컬럼 정의
categorical_cols = [
    'GENDER', 'EDU_NM', 'EDU_FNSH_SE', 'MARR_STTS', 'JOB_NM',
    'HOUSE_INCOME', 'TRAVEL_TERM',
    'TRAVEL_LIKE_SIDO_1', 'TRAVEL_LIKE_SIDO_2', 'TRAVEL_LIKE_SIDO_3',
]

numerical_cols = [
    'AGE_GRP', 'FAMILY_MEMB', 'TRAVEL_NUM', 'TRAVEL_COMPANIONS_NUM',
    'TRAVEL_STYL_1', 'TRAVEL_STYL_2', 'TRAVEL_STYL_3', 'TRAVEL_STYL_4',
    'TRAVEL_STYL_5', 'TRAVEL_STYL_6', 'TRAVEL_STYL_7', 'TRAVEL_STYL_8',
    'TRAVEL_MOTIVE_1', 'TRAVEL_MOTIVE_2',
    'INCOME'
]

use_cols = categorical_cols + numerical_cols

# 전처리용 데이터 필터링 (결측치 제거)
df_filtered = df[use_cols].dropna()

# %%
df_filtered.head(3).T
# Out:
#                           0     1     2
# GENDER                  2.0   1.0   1.0
# EDU_NM                  6.0   7.0   6.0
# EDU_FNSH_SE             1.0   5.0   1.0
# MARR_STTS               1.0   1.0   1.0
# JOB_NM                 12.0   2.0   1.0
# HOUSE_INCOME            7.0  10.0   7.0
# TRAVEL_TERM             3.0   2.0   3.0
# TRAVEL_LIKE_SIDO_1     50.0  48.0  46.0
# TRAVEL_LIKE_SIDO_2     50.0  48.0  45.0
# TRAVEL_LIKE_SIDO_3     26.0  26.0  47.0
# AGE_GRP                20.0  40.0  20.0
# FAMILY_MEMB             3.0   2.0   3.0
# TRAVEL_NUM              4.0   2.0   7.0
# TRAVEL_COMPANIONS_NUM   1.0   1.0   1.0
# TRAVEL_STYL_1           1.0   1.0   2.0
# TRAVEL_STYL_2           1.0   1.0   3.0
# TRAVEL_STYL_3           1.0   3.0   1.0
# TRAVEL_STYL_4           3.0   6.0   4.0
# TRAVEL_STYL_5           3.0   4.0   6.0
# TRAVEL_STYL_6           2.0   2.0   3.0
# TRAVEL_STYL_7           6.0   7.0   1.0
# TRAVEL_STYL_8           6.0   7.0   7.0
# TRAVEL_MOTIVE_1         1.0   1.0   7.0
# TRAVEL_MOTIVE_2         3.0   2.0   5.0
# INCOME                  2.0   5.0   4.0
