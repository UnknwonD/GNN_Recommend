# %%
import pandas as pd

# %%
data_path = './merged_csv/merged_csv_region/제주도 및 도서지역/'

df = pd.read_csv(data_path + '여행객_total.csv')

# %%
df.shape
# Out:
# (2880, 38)

# %%
df.drop('JOB_ETC', axis=1, inplace=True)

# %%
df['GENDER'] = df['GENDER'].map({'남': 1, '여': 2})

# %%
df.head().T
# Out:
#                                                0                      1  \
# TRAVELER_ID                              g003414                h006468
# RESIDENCE_SGG_CD                              30                     50
# GENDER                                         1                      1
# AGE_GRP                                       20                     40
# EDU_NM                                         5                      7
# EDU_FNSH_SE                                    1                      1
# MARR_STTS                                      1                      2
# FAMILY_MEMB                                    1                      3
# JOB_NM                                         3                      1
# INCOME                                         1                      8
# HOUSE_INCOME                                 NaN                    8.0
# TRAVEL_TERM                                    2                      2
# TRAVEL_NUM                                     2                      2
# TRAVEL_LIKE_SIDO_1                            27                     50
# TRAVEL_LIKE_SGG_1                          27290                  50130
# TRAVEL_LIKE_SIDO_2                            26                     50
# TRAVEL_LIKE_SGG_2                          26290                  50110
# TRAVEL_LIKE_SIDO_3                            47                     30
# TRAVEL_LIKE_SGG_3                          47110                  30140
# TRAVEL_STYL_1                                  3                      1
# TRAVEL_STYL_2                                  4                      1
# TRAVEL_STYL_3                                  2                      1
# TRAVEL_STYL_4                                  3                      1
# TRAVEL_STYL_5                                  6                      1
# TRAVEL_STYL_6                                  3                      1
# TRAVEL_STYL_7                                  1                      1
# TRAVEL_STYL_8                                  7                      6
# TRAVEL_STATUS_RESIDENCE                    대전광역시                제주특별자치도
# TRAVEL_STATUS_DESTINATION                     전남                     제주
# TRAVEL_STATUS_ACCOMPANY              2인 여행(가족 외)               자녀 동반 여행
# TRAVEL_STATUS_YMD          2023-07-08~2023-07-09  2023-09-16~2023-09-16
# TRAVEL_MOTIVE_1                                1                      8
# TRAVEL_MOTIVE_2                              2.0                    7.0
# TRAVEL_MOTIVE_3                              3.0                    1.0
# TRAVEL_COMPANIONS_NUM                          1                      2
# REGION                                제주도 및 도서지역             제주도 및 도서지역
# DATA_TYPE                             _csv_train             _csv_train
#
#                                                2                      3  \
# TRAVELER_ID                              h003272                h006175
# RESIDENCE_SGG_CD                              50                     27
# GENDER                                         2                      2
# AGE_GRP                                       50                     20
# EDU_NM                                         7                      7
# EDU_FNSH_SE                                    1                      1
# MARR_STTS                                      1                      1
# FAMILY_MEMB                                    1                      3
# JOB_NM                                         2                      2
# INCOME                                         4                      6
# HOUSE_INCOME                                 NaN                    6.0
# TRAVEL_TERM                                    2                      3
# TRAVEL_NUM                                     1                      2
# TRAVEL_LIKE_SIDO_1                            50                     26
# TRAVEL_LIKE_SGG_1                          50130                  26350
# TRAVEL_LIKE_SIDO_2                            50                     26
# TRAVEL_LIKE_SGG_2                          50110                  26710
# TRAVEL_LIKE_SIDO_3                            42                     47
# TRAVEL_LIKE_SGG_3                          42170                  47110
# TRAVEL_STYL_1                                  3                      4
# TRAVEL_STYL_2                                  4                      5
# TRAVEL_STYL_3                                  4                      4
# TRAVEL_STYL_4                                  4                      1
# TRAVEL_STYL_5                                  5                      4
# TRAVEL_STYL_6                                  2                      4
# TRAVEL_STYL_7                                  6                      3
# TRAVEL_STYL_8                                  5                      5
# TRAVEL_STATUS_RESIDENCE                  제주특별자치도                  대구광역시
# TRAVEL_STATUS_DESTINATION                     제주                     제주
# TRAVEL_STATUS_ACCOMPANY                   나홀로 여행                 나홀로 여행
# TRAVEL_STATUS_YMD          2023-08-27~2023-08-27  2023-09-06~2023-09-07
# TRAVEL_MOTIVE_1                                6                      1
# TRAVEL_MOTIVE_2                              1.0                    4.0
# TRAVEL_MOTIVE_3                              2.0                    5.0
# TRAVEL_COMPANIONS_NUM                          0                      0
# REGION                                제주도 및 도서지역             제주도 및 도서지역
# DATA_TYPE                             _csv_train             _csv_train
#
#                                                4
# TRAVELER_ID                              e000899
# RESIDENCE_SGG_CD                              11
# GENDER                                         2
# AGE_GRP                                       30
# EDU_NM                                         6
# EDU_FNSH_SE                                    1
# MARR_STTS                                      1
# FAMILY_MEMB                                    3
# JOB_NM                                         2
# INCOME                                         5
# HOUSE_INCOME                                10.0
# TRAVEL_TERM                                    2
# TRAVEL_NUM                                     1
# TRAVEL_LIKE_SIDO_1                            42
# TRAVEL_LIKE_SGG_1                          42150
# TRAVEL_LIKE_SIDO_2                            50
# TRAVEL_LIKE_SGG_2                          50130
# TRAVEL_LIKE_SIDO_3                            41
# TRAVEL_LIKE_SGG_3                          41650
# TRAVEL_STYL_1                                  3
# TRAVEL_STYL_2                                  2
# TRAVEL_STYL_3                                  4
# TRAVEL_STYL_4                                  3
# TRAVEL_STYL_5                                  4
# TRAVEL_STYL_6                                  5
# TRAVEL_STYL_7                                  6
# TRAVEL_STYL_8                                  3
# TRAVEL_STATUS_RESIDENCE                    서울특별시
# TRAVEL_STATUS_DESTINATION                     경기
# TRAVEL_STATUS_ACCOMPANY                 부모 동반 여행
# TRAVEL_STATUS_YMD          2023-05-27~2023-05-29
# TRAVEL_MOTIVE_1                                2
# TRAVEL_MOTIVE_2                              3.0
# TRAVEL_MOTIVE_3                              1.0
# TRAVEL_COMPANIONS_NUM                          2
# REGION                                제주도 및 도서지역
# DATA_TYPE                             _csv_train

# %%
# 사용할 컬럼 정의
categorical_cols = [
    'GENDER', 'EDU_NM', 'EDU_FNSH_SE', 'MARR_STTS', 'JOB_NM',
    'HOUSE_INCOME', 'TRAVEL_TERM',
    'TRAVEL_LIKE_SIDO_1', 'TRAVEL_LIKE_SIDO_2', 'TRAVEL_LIKE_SIDO_3',
]

numerical_cols = [
    'AGE_GRP', 'FAMILY_MEMB', 'TRAVEL_NUM', 'TRAVEL_COMPANIONS_NUM',
    'TRAVEL_STYL_1', 'TRAVEL_STYL_2', 'TRAVEL_STYL_3', 'TRAVEL_STYL_4',
    'TRAVEL_STYL_5', 'TRAVEL_STYL_6', 'TRAVEL_STYL_7', 'TRAVEL_STYL_8',
    'TRAVEL_MOTIVE_1', 'TRAVEL_MOTIVE_2',
    'INCOME'
]

use_cols = categorical_cols + numerical_cols

# 전처리용 데이터 필터링 (결측치 제거)
df_filtered = df[use_cols].dropna()

# %%
df_filtered.head(3).T
# Out:
#                           1     3     4
# GENDER                  1.0   2.0   2.0
# EDU_NM                  7.0   7.0   6.0
# EDU_FNSH_SE             1.0   1.0   1.0
# MARR_STTS               2.0   1.0   1.0
# JOB_NM                  1.0   2.0   2.0
# HOUSE_INCOME            8.0   6.0  10.0
# TRAVEL_TERM             2.0   3.0   2.0
# TRAVEL_LIKE_SIDO_1     50.0  26.0  42.0
# TRAVEL_LIKE_SIDO_2     50.0  26.0  50.0
# TRAVEL_LIKE_SIDO_3     30.0  47.0  41.0
# AGE_GRP                40.0  20.0  30.0
# FAMILY_MEMB             3.0   3.0   3.0
# TRAVEL_NUM              2.0   2.0   1.0
# TRAVEL_COMPANIONS_NUM   2.0   0.0   2.0
# TRAVEL_STYL_1           1.0   4.0   3.0
# TRAVEL_STYL_2           1.0   5.0   2.0
# TRAVEL_STYL_3           1.0   4.0   4.0
# TRAVEL_STYL_4           1.0   1.0   3.0
# TRAVEL_STYL_5           1.0   4.0   4.0
# TRAVEL_STYL_6           1.0   4.0   5.0
# TRAVEL_STYL_7           1.0   3.0   6.0
# TRAVEL_STYL_8           6.0   5.0   3.0
# TRAVEL_MOTIVE_1         8.0   1.0   2.0
# TRAVEL_MOTIVE_2         7.0   4.0   3.0
# INCOME                  8.0   6.0   5.0

# %%
df_filtered.to_csv(data_path + 'fin/여행객_fin.csv')
